# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Scikit-Learn Version:", sklearn.__version__)
# Out:
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
# Scikit-Learn Version: 1.6.1

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e56aa54d-9c2f-44e0-999e-84d2ca443534" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e56aa54d-9c2f-44e0-999e-84d2ca443534">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "CIFPS - DATASET A.zip"
extract_path = "/content/datasetA"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset A Extracted Successfully")
# Out:
# Dataset A Extracted Successfully

# %%
df_a = pd.read_csv(
    "/content/datasetA/cloud-monitoring-dataset-master/data/application-crash-rate-2/app2-01.csv"
)

print("Shape:", df_a.shape)

df_a.head()
# Out:
# Shape: (1114, 3)
#              TimeStamp     Value  Label
# 0  2018-05-10 00:00:00  0.040000      0
# 1  2018-05-10 01:00:00  0.007634      0
# 2  2018-05-10 02:00:00  0.009524      0
# 3  2018-05-10 03:00:00  0.000000      0
# 4  2018-05-10 04:00:00  0.019231      0

# %%
df_a.isnull().sum()
# Out:
# TimeStamp    0
# Value        0
# Label        0
# dtype: int64

# %%
plt.figure(figsize=(12,4))
plt.plot(df_a["Value"])
plt.title("Dataset A - Metric Values")
plt.show()

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e893452d-fe16-49f5-9a64-4caab4292b55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e893452d-fe16-49f5-9a64-4caab4292b55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "CIFPS - DATASET B.zip"
extract_path = "/content/datasetB"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset B Extracted Successfully")
# Out:
# Dataset B Extracted Successfully

# %%
depl_df = pd.read_csv(
    "/content/datasetB/Failure-Dataset-OpenStack-main/DEPL/SEQ.tsv",
    sep="\t"
)

print("Shape:", depl_df.shape)

depl_df.head()
# Out:
# Shape: (1076, 104)
#    cinderclient_DELETE_202  cinderclient_DELETE_400  cinderclient_DELETE_500  \
# 0                        1                        0                        0
# 1                        1                        0                        0
# 2                        1                        0                        0
# 3                        1                        0                        0
# 4                        1                        0                        0
#
#    cinderclient_GET_200  cinderclient_GET_400  cinderclient_GET_404  \
# 0                    10                     0                     1
# 1                    10                     0                     1
# 2                    10                     0                     1
# 3                    10                     0                     1
# 4                    10                     0                     1
#
#    cinderclient_GET_500  cinderclient_POST_200  cinderclient_POST_202  \
# ...

# %%
labels = pd.read_csv(
    "/content/datasetB/Failure-Dataset-OpenStack-main/DEPL/Failure_Labels.txt",
    header=None
)

labels.head()
# Out:
#    0
# 0  6
# 1  6
# 2  6
# 3  6
# 4  6

# %%
labels[0].value_counts().sort_index()
# Out:
# 0
# 1    224
# 2    151
# 3     41
# 4     69
# 5     52
# 6    539
# Name: count, dtype: int64

# %%
labels[0].value_counts().sort_index().plot(kind="bar")

plt.title("Failure Class Distribution - DEPL")
plt.xlabel("Failure Class")
plt.ylabel("Count")
plt.show()
